# %%
data=[
    "hello",
    "go india",
    "hipp hipp hurray",
    "deep learning is fun",
    "recurrent neural networks"
    "wow great",
    "Zara si dil me de jaga tu ",
    "zara sa yaado me basaa",
    "hii",
    "bye"
]

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer=Tokenizer(oov_token='<Nothing>')

# %%
tokenizer.fit_on_texts(data)

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('hello', 1),
#              ('go', 1),
#              ('india', 1),
#              ('hipp', 2),
#              ('hurray', 1),
#              ('deep', 1),
#              ('learning', 1),
#              ('is', 1),
#              ('fun', 1),
#              ('recurrent', 1),
#              ('neural', 1),
#              ('networkswow', 1),
#              ('great', 1),
#              ('zara', 2),
#              ('si', 1),
#              ('dil', 1),
#              ('me', 2),
#              ('de', 1),
#              ('jaga', 1),
#              ('tu', 1),
#              ('sa', 1),
#              ('yaado', 1),
#              ('basaa', 1),
#              ('hii', 1),
#              ('bye', 1)])

# %%
tokenizer.word_docs
# Out:
# defaultdict(int,
#             {'hello': 1,
#              'india': 1,
#              'go': 1,
#              'hurray': 1,
#              'hipp': 1,
#              'fun': 1,
#              'is': 1,
#              'deep': 1,
#              'learning': 1,
#              'recurrent': 1,
#              'great': 1,
#              'networkswow': 1,
#              'neural': 1,
#              'de': 1,
#              'tu': 1,
#              'jaga': 1,
#              'me': 2,
#              'zara': 2,
#              'si': 1,
#              'dil': 1,
#              'sa': 1,
#              'yaado': 1,
#              'basaa': 1,
#              'hii': 1,
#              'bye': 1})

# %%
tokenizer.word_index
# Out:
# {'<Nothing>': 1,
#  'hipp': 2,
#  'zara': 3,
#  'me': 4,
#  'hello': 5,
#  'go': 6,
#  'india': 7,
#  'hurray': 8,
#  'deep': 9,
#  'learning': 10,
#  'is': 11,
#  'fun': 12,
#  'recurrent': 13,
#  'neural': 14,
#  'networkswow': 15,
#  'great': 16,
#  'si': 17,
#  'dil': 18,
#  'de': 19,
#  'jaga': 20,
#  'tu': 21,
#  'sa': 22,
#  'yaado': 23,
#  'basaa': 24,
#  'hii': 25,
#  'bye': 26}

# %%
seq = tokenizer.texts_to_sequences(data) # converting text to sequence of integers how it convert to sequence

# %%
seq
# Out:
# [[5],
#  [6, 7],
#  [2, 2, 8],
#  [9, 10, 11, 12],
#  [13, 14, 15, 16],
#  [3, 17, 18, 4, 19, 20, 21],
#  [3, 22, 23, 4, 24],
#  [25],
#  [26]]

# %%
seq = pad_sequences(seq, padding='post')  # padding the sequences to make them of equal length

# %%
seq
# Out:
# array([[ 5,  0,  0,  0,  0,  0,  0],
#        [ 6,  7,  0,  0,  0,  0,  0],
#        [ 2,  2,  8,  0,  0,  0,  0],
#        [ 9, 10, 11, 12,  0,  0,  0],
#        [13, 14, 15, 16,  0,  0,  0],
#        [ 3, 17, 18,  4, 19, 20, 21],
#        [ 3, 22, 23,  4, 24,  0,  0],
#        [25,  0,  0,  0,  0,  0,  0],
#        [26,  0,  0,  0,  0,  0,  0]], dtype=int32)

# %% [markdown]
# # This is how we convert the text data to numbers

# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Embedding, Flatten

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data()
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (25000,)
# (25000,)

# %%
(x_train[0] ) # first review in training data represented as sequence of integers
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
# ...

# %%
x_train = pad_sequences(x_train, padding='post',maxlen=50)
x_test = pad_sequences(x_test, padding='post',maxlen=50)

# %%
x_train.shape
# Out:
# (25000, 50)

# %%
x_train[0].shape
# Out:
# (50,)

# %%
model = Sequential()

# %%
model.add(SimpleRNN(32, input_shape=(50,1), return_sequences=False))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.5023 - loss: 0.7949 - val_accuracy: 0.5010 - val_loss: 0.6943
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5083 - loss: 0.6931 - val_accuracy: 0.5046 - val_loss: 0.6940
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.5063 - loss: 0.6925 - val_accuracy: 0.5032 - val_loss: 0.6950
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.5054 - loss: 0.6922 - val_accuracy: 0.5012 - val_loss: 0.6944
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5032 - loss: 0.6924 - val_accuracy: 0.5014 - val_loss: 0.6955

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data()

# %%
x_train = pad_sequences(x_train, padding='post',maxlen=150,truncating='post')
x_test = pad_sequences(x_test, padding='post',maxlen=150,truncating='post')

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
model1 = Sequential()
model1.add(SimpleRNN(32, input_shape=(150,1), return_sequences=False))
model1.add(Dense(1, activation='sigmoid'))

# %%
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model1.fit(x_train, y_train, epochs=15, validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 14ms/step - accuracy: 0.4972 - loss: 0.6939 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.4911 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.5028 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.4970 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6933
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4989 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.4982 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.4952 - loss: 0.6933 - val_accuracy: 0.5000 - val_loss: 0.6932
# Epoch 8/15
# ...

# %% [markdown]
# # Using Embedding layer

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data()

# %%
x_train = pad_sequences(x_train, padding='post',maxlen=150,truncating='post')
x_test = pad_sequences(x_test, padding='post',maxlen=150,truncating='post')

# %%
model = Sequential()
model.add(Embedding(10000, 32, input_length=150))
model.add(SimpleRNN(32, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=15, validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.5137 - loss: 0.6950 - val_accuracy: 0.5618 - val_loss: 0.6858
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.6283 - loss: 0.6509 - val_accuracy: 0.5020 - val_loss: 0.7209
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.7615 - loss: 0.4752 - val_accuracy: 0.5786 - val_loss: 0.7448
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.8662 - loss: 0.2805 - val_accuracy: 0.5248 - val_loss: 1.0444
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9058 - loss: 0.2038 - val_accuracy: 0.5157 - val_loss: 1.2301
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9075 - loss: 0.1850 - val_accuracy: 0.5223 - val_loss: 1.3810
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9307 - loss: 0.1446 - val_accuracy: 0.5080 - val_loss: 1.5495
# Epoch 8/15
# ...

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 150, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 966,341 (3.69 MB)
#  Trainable params: 322,113 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 644,228 (2.46 MB)

# %% [markdown]
# # After Embeddings model accuracy increases
